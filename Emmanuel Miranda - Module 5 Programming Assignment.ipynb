# %%
#from test_sum.py
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    print("Everything passed")

#python test_sum.py
# Out:
# Everything passed

# %%
#from test_sum_2.py
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")
    
#python test_sum_2.py
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[16], line 10
#       8 if __name__ == "__main__":
#       9     test_sum()
# ---> 10     test_sum_tuple()
#      11     print("Everything passed")
#
# Cell In[16], line 6, in test_sum_tuple()
#       5 def test_sum_tuple():
# ----> 6     assert sum((1, 2, 2)) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
#from test_sum_unittest
import unittest


class TestSum(unittest.TestCase):

    def test_sum(self):
        self.assertEqual(sum([1, 2, 3]), 6, "Should be 6")

    def test_sum_tuple(self):
        self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")

if __name__ == "__main_":
    unittest.main()

#python test_sum_unittest.py

# %%
#from CMND PROMPT
#pip install nose2
#python -m nose2

# %%
#from pytest
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

# %%
#from test.py
import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

if __name__ == "__main_":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 #from test.py
#       2 import unittest
# ----> 4 from my_sum import sum
#       7 class TestSum(unittest.TestCase):
#       8     def test_list_int(self):
#
# ImportError: cannot import name 'sum' from 'my_sum' (unknown location)

# %%
#from CMND PROMPT
#python -m unittest test
#OUTPUT:
# .
#----------------------------------------------------------------------
#Ran 1 test in 0.000s

#OK
#python -m unittest -v test
#OUTPUT:
#test_list_int (test.TestSum.test_list_int)
#Test that it can sum a list of integers ... ok

#----------------------------------------------------------------------
#Ran 1 test in 0.000s

#OK

#python -m unittest discover
#OUTPUT:
#F..F.
#======================================================================
#FAIL: test_list_fraction (my_sum.test.TestSum.test_list_fraction)
#Test that it can sum a list of fractions
#----------------------------------------------------------------------
#Traceback (most recent call last):
#  File "C:\Users\EJRAI\Emmanuel Miranda - Software Development\project\my_sum\test.py", line 23, in test_list_fraction
#    self.assertEqual(result, 1)
#    ~~~~~~~~~~~~~~~~^^^^^^^^^^^
#AssertionError: Fraction(9, 10) != 1

#======================================================================
#FAIL: test_sum_tuple (my_sum.test_sum_unittest.TestSum.test_sum_tuple)
#----------------------------------------------------------------------
#Traceback (most recent call last):
#  File "C:\Users\EJRAI\Emmanuel Miranda - Software Development\project\my_sum\test_sum_unittest.py", line 10, in test_sum_tuple
#    self.assertEqual(sum((1, 2, 2)), 6, "Should be 6")
#    ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#AssertionError: 5 != 6 : Should be 6

#----------------------------------------------------------------------
#Ran 5 tests in 0.001s

#FAILED (failures=2)

#python -m unittest discover -s tests
#OUTPUT:
#Traceback (most recent call last):
#  File "<frozen runpy>", line 198, in _run_module_as_main
#  File "<frozen runpy>", line 88, in _run_code
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\__main__.py", line 18, in <module>
#    main(module=None)
#    ~~~~^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 103, in __init__
#    self.parseArgs(argv)
#    ~~~~~~~~~~~~~~^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 119, in parseArgs
#    self._do_discovery(argv[2:])
#    ~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 242, in _do_discovery
#    self.createTests(from_discovery=True, Loader=Loader)
#    ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 149, in createTests
#    self.test = loader.discover(self.start, self.pattern, self.top)
#                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\loader.py", line 334, in discover
#    raise ImportError('Start directory is not importable: %r' % start_dir)
#ImportError: Start directory is not importable: 'tests'

#python -m unittest discover -s tests -t src
#OUTPUT:
#Traceback (most recent call last):
#  File "<frozen runpy>", line 198, in _run_module_as_main
#  File "<frozen runpy>", line 88, in _run_code
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\__main__.py", line 18, in <module>
#    main(module=None)
#    ~~~~^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 103, in __init__
#    self.parseArgs(argv)
#    ~~~~~~~~~~~~~~^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 119, in parseArgs
#    self._do_discovery(argv[2:])
#    ~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 242, in _do_discovery
#    self.createTests(from_discovery=True, Loader=Loader)
#    ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\main.py", line 149, in createTests
#    self.test = loader.discover(self.start, self.pattern, self.top)
#                ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#  File "C:\Users\EJRAI\AppData\Local\Programs\Python\Python314\Lib\unittest\loader.py", line 334, in discover
#    raise ImportError('Start directory is not importable: %r' % start_dir)
#ImportError: Start directory is not importable: 'tests'

# %%
#from test.py (update 2)
from fractions import Fraction

import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

if __name__ == "__main_":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 6
#       2 from fractions import Fraction
#       4 import unittest
# ----> 6 from my_sum import sum
#       9 class TestSum(unittest.TestCase):
#      10     def test_list_int(self):
#
# ImportError: cannot import name 'sum' from 'my_sum' (unknown location)

# %%
#from CMND PROMPT
#python -m unittest test

# %%
#from test.py (Update 3)
from fractions import Fraction

import unittest

from my_sum import sum


class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """
        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1, 4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)

if __name__ == "__main_":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 6
#       2 from fractions import Fraction
#       4 import unittest
# ----> 6 from my_sum import sum
#       9 class TestSum(unittest.TestCase):
#      10     def test_list_int(self):
#
# ImportError: cannot import name 'sum' from 'my_sum' (unknown location)

# %%
What do the Test Results Mean?:
The different symbols and outputs help serve as a kind of diagnostic dashboard when it comes to code quality.
When the code is executed and outputs a passing test, it will show a "." which confirms that all inputs are being handled in the correct way.
Additionally, if "F" is shown, it helps us know that there were errors within our code, usually isolating different functions or inputs.
This is seen in the 3rd edit of test.py because it shows that it doesn't "do well" with fractional precision as it normally should.
Additionally, the summary line after executing different test commands, such as "Ran 2 tests in 0.001s\nFAILED (failures=1)"
helps tell us the different things that were done with the tested files, such as the amount of tests done and how quickly it was done,
as well as if it failed or succeeded.
# Out:
#   Cell In[11], line 5
#     This is seen in the 3rd edit of test.py because it shows that it doesn't "do well" with fractional precision as it normally should.
#                         ^
# SyntaxError: invalid decimal literal
