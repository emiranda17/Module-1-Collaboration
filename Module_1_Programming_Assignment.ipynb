# %%
minute = 60
second = 60
hours = int(input("Welcome! Please enter desired amount of hours here:\n"))
operation = (minute * second) * hours
print("You have selected", hours, "hour(s),\nThis means that there are:", operation, "seconds in", hours, "hour(s)!")
# Out:
# Welcome! Please enter desired amount of hours here:
#  1
# You have selected 1 hour(s),
# This means that there are: 3600 seconds in 1 hour(s)!

# %%
seconds_per_hour = 3600
hours = 24
days = int(input("Please input the amount of days desired:"))
operation2 = (seconds_per_hour * hours) * days
print("As requested, there are", operation2, "seconds in", days, "day(s).")
# Out:
# Please input the amount of days desired: 1
# As requested, there are 86400 seconds in 1 day(s).

# %%
seconds_per_hour = 3600
hours = 24
days = int(input("Please input the amount of days desired:"))
operation2 = (seconds_per_hour * hours) * days
print("As requested, there are", operation2, "seconds in", days, "day(s).")
seconds_per_day = operation2
operation3 = seconds_per_day / seconds_per_hour
print("The floating point answer after dividing seconds per day and\nseconds per hour is:", operation3, "!")
# Out:
# Please input the amount of days desired: 1
# As requested, there are 86400 seconds in 1 day(s).
# The floating point answer after dividing seconds per day and
# seconds per hour is: 24.0 !

# %%
seconds_per_hour = 3600
hours = 24
days = int(input("Please input the amount of days desired:"))
operation2 = (seconds_per_hour * hours) * days
print("As requested, there are", operation2, "seconds in", days, "day(s).")
seconds_per_day = operation2
operation3 = seconds_per_day / seconds_per_hour
print("The floating point answer after dividing seconds per day and\nseconds per hour is:", operation3, "!")
operation4 = seconds_per_day // seconds_per_hour
print("")
