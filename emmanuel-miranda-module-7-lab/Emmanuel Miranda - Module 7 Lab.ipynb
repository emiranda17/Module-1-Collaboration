# %%
# CREATE & SETUP

import pandas as pd

# Read CSV data into a DataFrame
# Make sure 'telco_churn.csv' is in the same directory as this notebook
df = pd.read_csv("telco_churn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 7
#       3 import pandas as pd
#       5 # Read CSV data into a DataFrame
#       6 # Make sure 'telco_churn.csv' is in the same directory as this notebook
# ----> 7 df = pd.read_csv("telco_churn.csv")
#
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 5 rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 5 rows
df.tail()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for numeric columns
df.describe()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[26], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]

# Convert churn True/False to 1/0 in a new column
df['churn_binary'] = df['churn'].apply(lambda x: 1 if x == True else 0)

# Check the relationship between churn and churn_binary
df[['churn', 'churn_binary']].head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]

# Convert churn True/False to 1/0 in a new column
df['churn_binary'] = df['churn'].apply(lambda x: 1 if x == True else 0)

# Check the relationship between churn and churn_binary
df[['churn', 'churn_binary']].head()

# Output to CSV
df.to_csv('output.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]

# Convert churn True/False to 1/0 in a new column
df['churn_binary'] = df['churn'].apply(lambda x: 1 if x == True else 0)

# Check the relationship between churn and churn_binary
df[['churn', 'churn_binary']].head()

# Output to CSV
df.to_csv('output.csv', index=False)

# Output to JSON (record-oriented)
df.to_json('output.json', orient='records')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]

# Convert churn True/False to 1/0 in a new column
df['churn_binary'] = df['churn'].apply(lambda x: 1 if x == True else 0)

# Check the relationship between churn and churn_binary
df[['churn', 'churn_binary']].head()

# Output to CSV
df.to_csv('output.csv', index=False)

# Output to JSON (record-oriented)
df.to_json('output.json', orient='records')

# Output to HTML
df.to_html('output.html')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd
df = pd.read_csv('telco_churn.csv')

# View the first 10 rows
df.head(10)

data_dict = {
    'Name': ['Nick', 'Kate', 'John', 'Sara'],
    'Age': [29, 24, 31, 27],
    'Country': ['USA', 'Canada', 'UK', 'Australia']
}

df_dict = pd.DataFrame.from_dict(data_dict)
df_dict.head()

# Bottom 15 rows
df.tail(15)

# List all columns
df.columns

# Data types of each column
df.dtypes

# Summary statistics for object (categorical) columns
df.describe(include='object')

# Single column without spaces in its name
df['state'].head()

# Column with a space in the name (example: 'international plan')
df['international plan'].head()

# Multiple columns at once
df[['state', 'international plan']].head()

# Unique values in the 'state' column
df['state'].unique()

# Unique values in the 'churn' column
df['churn'].unique()

# Rows where international plan is 'No'
df[df['international plan'] == 'No'].head()

# Rows where international plan is 'No' AND churn is True
df_filtered = df[(df['international plan'] == 'No') & (df['churn'] == True)]
df_filtered.head()

# 15th row (index 14)
df.iloc[14]

# 15th row, first column
df.iloc[14, 0]

# 15th row, last column
df.iloc[14, -1]

# Rows 22 to 32 (33 is excluded)
df.iloc[22:33]

# Set 'state' as the index in place
df.set_index('state', inplace=True)

# Filter rows for a specific state, e.g. 'OHIO'
df.loc['OHIO']

# Count missing values per column
df.isnull().sum()

# Drop rows with any missing values, in place
df.dropna(inplace=True)

# Confirm that missing values have been removed
df.isnull().sum()

# Drop the 'area code' column
df.drop('area code', axis=1, inplace=True)

# Create a new calculated column
df['new_column'] = df['total night minutes'] + df['total intl minutes']

# Overwrite the entire column with a constant value
df['new_column'] = 100

# Preview the updated column
df['new_column'].head()

# Update the first row, last column to 10
df.iloc[0, -1] = 10

# Confirm the update
df.iloc[0, -1]

# Convert churn True/False to 1/0 in a new column
df['churn_binary'] = df['churn'].apply(lambda x: 1 if x == True else 0)

# Check the relationship between churn and churn_binary
df[['churn', 'churn_binary']].head()

# Output to CSV
df.to_csv('output.csv', index=False)

# Output to JSON (record-oriented)
df.to_json('output.json', orient='records')

# Output to HTML
df.to_html('output.html')

# Delete the DataFrame
del df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('telco_churn.csv')
#       4 # View the first 10 rows
#       5 df.head(10)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
